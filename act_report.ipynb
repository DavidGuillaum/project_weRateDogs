# %% [markdown]
# # Act report
# The goal to this report is to communicate insights and display visualisations from the WeRateDogs project.

# %% [markdown]
# This report shows the results of a wrangling process in 3 steps: Gathering Data - Assessing Dat - Cleaning Data.
# Here are the 3 insights I discovered doing the project:
# ### Insight 1
# the most "loved" (in term of score) dogs are Pomeranian in average.
# Here have the most loved dogs in term of score in ascending order:  ![image.png](attachment:image.png)
# ### Insight 2
# the most "loved" (in term of likes) dogs are french bulldog in average
# Here have the most loved dogs in term of likes in ascending order:  ![image-2.png](attachment:image-2.png)
# ### Insight 3
# the dog's breed with the biggest difference between likes and score in average is the french bulldog. This insight could be described as the disagraeement in average between the twitter's account owner and his folowers.
# Here is the list of breeds with the biggest difference in ascending order: ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# For a better visualization the best would be do download the image and display it because the output here limit the size.
